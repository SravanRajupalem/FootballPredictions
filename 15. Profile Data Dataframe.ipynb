# %%
import datetime
from datetime import date
import requests
import pprint
from bs4 import BeautifulSoup
import pandas as pd
import re
import pickle
from urllib.request import urlopen
import glob
import altair as alt
import time
import itertools
import numpy as np
import operator

pd.options.display.max_columns = 100

# %%
# Helper Functions

def Filter(string, substr): 
        return [str for str in string if
                any(sub in str for sub in substr)] 
    
def NOTFilter(string, substr): 
    return [str for str in string if
            any(sub not in str for sub in substr)]

# %%
# England: 9 | Italy: 11 | Spain: 12 | France: 13 | Germany: 20
def fbref_league_history(league_id = [9,11,12,13,20], first_season = 2010):
    history = []
    for i in league_id:
        comp_history_url = "https://fbref.com/en/comps/" + str(i) + "/history" 
        #print(comp_history_url)

        r=requests.get(comp_history_url)
        soup=BeautifulSoup(r.content, "html.parser")

        find_seasons = soup.find_all(class_ = "left")

        all_seasons_url = []
        for k in range(0, len(find_seasons)):
            if find_seasons[k].get('data-stat') == "season":
                temp = "https://fbref.com" + find_seasons[k].find_all("a")[0].attrs["href"]
                all_seasons_url.append(temp)

        history.append(all_seasons_url)
        time.sleep(0.1)

    # All histories in one array
    history  = list(itertools.chain(*history))

    seasons = list(map(lambda x: str(x)+"-"+str(x+1), np.arange(1950, first_season, 1)))
    for i in seasons:
        history = NOTFilter(history, [i])
    del seasons

    return history

# %%
# Test for Big 5
history = fbref_league_history(league_id = [9,11,12,13,20])
history
# Out:
# ['https://fbref.com/en/comps/9/Premier-League-Stats',
#  'https://fbref.com/en/comps/9/10728/2020-2021-Premier-League-Stats',
#  'https://fbref.com/en/comps/9/3232/2019-2020-Premier-League-Stats',
#  'https://fbref.com/en/comps/9/1889/2018-2019-Premier-League-Stats',
#  'https://fbref.com/en/comps/9/1631/2017-2018-Premier-League-Stats',
#  'https://fbref.com/en/comps/9/1526/2016-2017-Premier-League-Stats',
#  'https://fbref.com/en/comps/9/1467/2015-2016-Premier-League-Stats',
#  'https://fbref.com/en/comps/9/733/2014-2015-Premier-League-Stats',
#  'https://fbref.com/en/comps/9/669/2013-2014-Premier-League-Stats',
#  'https://fbref.com/en/comps/9/602/2012-2013-Premier-League-Stats',
#  'https://fbref.com/en/comps/9/534/2011-2012-Premier-League-Stats',
#  'https://fbref.com/en/comps/9/467/2010-2011-Premier-League-Stats',
#  'https://fbref.com/en/comps/11/Serie-A-Stats',
#  'https://fbref.com/en/comps/11/10730/2020-2021-Serie-A-Stats',
#  'https://fbref.com/en/comps/11/3260/2019-2020-Serie-A-Stats',
#  'https://fbref.com/en/comps/11/1896/2018-2019-Serie-A-Stats',
#  'https://fbref.com/en/comps/11/1640/2017-2018-Serie-A-Stats',
#  'https://fbref.com/en/comps/11/1535/2016-2017-Serie-A-Stats',
#  'https://fbref.com/en/comps/11/1476/2015-2016-Serie-A-Stats',
#  'https://fbref.com/en/comps/11/742/2014-2015-Serie-A-Stats',
#  'https://fbref.com/en/comps/11/678/2013-2014-Serie-A-Stats',
#  'https://fbref.com/en/comps/11/611/2012-2013-Serie-A-Stats',
#  'https://fbref.com/en/comps/11/544/2011-2012-Serie-A-Stats',
#  'https://fbref.com/en/comps/11/477/2010-2011-Serie-A-Stats',
#  'https://fbref.com/en/comps/12/La-Liga-Stats',
#  'https://fbref.com/en/comps/12/10731/2020-2021-La-Liga-Stats',
#  'https://fbref.com/en/comps/12/3239/2019-2020-La-Liga-Stats',
#  'https://fbref.com/en/comps/12/1886/2018-2019-La-Liga-Stats',
#  'https://fbref.com/en/comps/12/1652/2017-2018-La-Liga-Stats',
#  'https://fbref.com/en/comps/12/1547/2016-2017-La-Liga-Stats',
#  'https://fbref.com/en/comps/12/1488/2015-2016-La-Liga-Stats',
#  'https://fbref.com/en/comps/12/755/2014-2015-La-Liga-Stats',
#  'https://fbref.com/en/comps/12/690/2013-2014-La-Liga-Stats',
#  'https://fbref.com/en/comps/12/624/2012-2013-La-Liga-Stats',
#  'https://fbref.com/en/comps/12/557/2011-2012-La-Liga-Stats',
#  'https://fbref.com/en/comps/12/488/2010-2011-La-Liga-Stats',
#  'https://fbref.com/en/comps/13/Ligue-1-Stats',
#  'https://fbref.com/en/comps/13/10732/2020-2021-Ligue-1-Stats',
#  'https://fbref.com/en/comps/13/3243/2019-2020-Ligue-1-Stats',
#  'https://fbref.com/en/comps/13/2104/2018-2019-Ligue-1-Stats',
#  'https://fbref.com/en/comps/13/1632/2017-2018-Ligue-1-Stats',
#  'https://fbref.com/en/comps/13/1527/2016-2017-Ligue-1-Stats',
#  'https://fbref.com/en/comps/13/1468/2015-2016-Ligue-1-Stats',
#  'https://fbref.com/en/comps/13/734/2014-2015-Ligue-1-Stats',
#  'https://fbref.com/en/comps/13/670/2013-2014-Ligue-1-Stats',
#  'https://fbref.com/en/comps/13/603/2012-2013-Ligue-1-Stats',
#  'https://fbref.com/en/comps/13/535/2011-2012-Ligue-1-Stats',
#  'https://fbref.com/en/comps/13/468/2010-2011-Ligue-1-Stats',
#  'https://fbref.com/en/comps/20/Bundesliga-Stats',
#  'https://fbref.com/en/comps/20/10737/2020-2021-Bundesliga-Stats',
#  'https://fbref.com/en/comps/20/3248/2019-2020-Bundesliga-Stats',
#  'https://fbref.com/en/comps/20/2109/2018-2019-Bundesliga-Stats',
#  'https://fbref.com/en/comps/20/1634/2017-2018-Bundesliga-Stats',
#  'https://fbref.com/en/comps/20/1529/2016-2017-Bundesliga-Stats',
#  'https://fbref.com/en/comps/20/1470/2015-2016-Bundesliga-Stats',
#  'https://fbref.com/en/comps/20/736/2014-2015-Bundesliga-Stats',
#  'https://fbref.com/en/comps/20/672/2013-2014-Bundesliga-Stats',
#  'https://fbref.com/en/comps/20/605/2012-2013-Bundesliga-Stats',
#  'https://fbref.com/en/comps/20/537/2011-2012-Bundesliga-Stats',
#  'https://fbref.com/en/comps/20/470/2010-2011-Bundesliga-Stats']

# %%
def fbref_team_url_history(league_history):
    team_season_url = []
    for league_season_url in league_history:
        r=requests.get(league_season_url)
        soup=BeautifulSoup(r.content, "html.parser")
        teams = soup.find("table").find_all("a")
        teams = list(map(lambda x: "https://fbref.com" + x["href"], teams))
        teams = Filter(teams, ["/en/squads/"])
        team_season_url.append(teams)

    # All histories in one array
    team_season_url  = list(itertools.chain(*team_season_url))
    return team_season_url

# %%
# Test for Premier League Last Season
team_season_url = fbref_team_url_history(history)
len(team_season_url)
# Out:
# 1176

# %%
def fbref_player_url(team_season_url):
    player_url = []
    for turl in team_season_url:
        r=requests.get(turl)
        soup=BeautifulSoup(r.content, "html.parser")
        soup.find("div", {"id":"all_stats_standard"})
        players = soup.find("tbody").find_all("a")
        players = list(map(lambda x: x["href"], players))
        players = Filter(players, ["/en/players/"])
        players = NOTFilter(players, ["matchlogs"])
        player_url.append(list(map(lambda x: "https://fbref.com" + x, players)))
        time.sleep(0.01)
    player_url  = list(itertools.chain(*player_url))
    return player_url

# %%
# Test for players urls
player_url = fbref_player_url(team_season_url)
player_url
# Out:
# ['https://fbref.com/en/players/33887998/Edouard-Mendy',
#  'https://fbref.com/en/players/18b896d6/Antonio-Rudiger',
#  'https://fbref.com/en/players/45db685d/Jorginho',
#  'https://fbref.com/en/players/1cb49278/Andreas-Christensen',
#  'https://fbref.com/en/players/79c0821a/Mateo-Kovacic',
#  'https://fbref.com/en/players/53cad200/Cesar-Azpilicueta',
#  'https://fbref.com/en/players/5eae500a/Romelu-Lukaku',
#  'https://fbref.com/en/players/fed7cb61/Kai-Havertz',
#  'https://fbref.com/en/players/86e7deaf/Thiago-Silva',
#  'https://fbref.com/en/players/f4290206/Marcos-Alonso',
#  'https://fbref.com/en/players/1265a93a/Reece-James',
#  'https://fbref.com/en/players/5515376c/Trevoh-Chalobah',
#  'https://fbref.com/en/players/9674002f/Mason-Mount',
#  'https://fbref.com/en/players/d2424d1b/Ben-Chilwell',
#  'https://fbref.com/en/players/b9fbae28/NGolo-Kante',
#  'https://fbref.com/en/players/15f3ec41/Callum-Hudson-Odoi',
#  'https://fbref.com/en/players/49fe9070/Timo-Werner',
#  'https://fbref.com/en/players/e97fd090/Ruben-Loftus-Cheek',
#  'https://fbref.com/en/players/6622454d/Hakim-Ziyech',
#  'https://fbref.com/en/players/3a24769f/Ross-Barkley',
#  'https://fbref.com/en/players/28d596a0/Kepa-Arrizabalaga',
#  'https://fbref.com/en/players/4315f30d/Malang-Sarr',
#  'https://fbref.com/en/players/1bf33a9a/Christian-Pulisic',
#  'https://fbref.com/en/players/c14bc029/Saul-Niguez',
#  'https://fbref.com/en/players/e0bc6fdc/Emerson-Palmieri',
#  'https://fbref.com/en/players/f586779e/Tammy-Abraham',
#  'https://fbref.com/en/players/0d85a4e8/Marcus-Bettinelli',
#  'https://fbref.com/en/players/ce4246f5/Kurt-Zouma',
#  'https://fbref.com/en/players/bd6351cd/Joao-Cancelo',
#  'https://fbref.com/en/players/31c69ef1/Ruben-Dias',
#  'https://fbref.com/en/players/3bb7b8b4/Ederson',
#  'https://fbref.com/en/players/3eb22ec9/Bernardo-Silva',
#  'https://fbref.com/en/players/6434f10d/Rodri',
#  'https://fbref.com/en/players/b66315ae/Gabriel-Jesus',
#  'https://fbref.com/en/players/86dd77d1/Kyle-Walker',
#  'https://fbref.com/en/players/79300479/Martin-Odegaard',
#  'https://fbref.com/en/players/dc6f5bdd/Calum-Chambers',
#  'https://fbref.com/en/players/839c14e1/Cedric-Soares',
#  'https://fbref.com/en/players/48a5a5d6/Martinelli',
#  'https://fbref.com/en/players/e3a5814e/Ainsley-Maitland-Niles',
#  'https://fbref.com/en/players/a53649b7/Eddie-Nketiah',
#  'https://fbref.com/en/players/4535e4bb/Mathew-Ryan',
#  'https://fbref.com/en/players/a3b03921/Joe-Willock',
#  'https://fbref.com/en/players/3935e52e/Sead-Kolasinac',
#  'https://fbref.com/en/players/c5bdb6e3/Reiss-Nelson',
#  'https://fbref.com/en/players/3f2d59fe/Shkodran-Mustafi',
#  'https://fbref.com/en/players/8fa8f8d2/Runar-Alex-Runarsson',
#  'https://fbref.com/en/players/660e71be/Miguel-Azeez',
#  'https://fbref.com/en/players/136e7649/Matt-Macey',
#  'https://fbref.com/en/players/67ca8566/Stuart-Dallas',
#  'https://fbref.com/en/players/420d7c7d/Luke-Ayling',
#  'https://fbref.com/en/players/93feac6e/Patrick-Bamford',
#  'https://fbref.com/en/players/6b625ac2/Illan-Meslier',
#  'https://fbref.com/en/players/aa849a12/Jack-Harrison',
#  'https://fbref.com/en/players/1a7fcf39/Ezgjan-Alioski',
#  'https://fbref.com/en/players/4f565d77/Kalvin-Phillips',
#  'https://fbref.com/en/players/282679b4/Mateusz-Klich',
#  'https://fbref.com/en/players/3423f250/Raphael-Dias-Belloli',
#  'https://fbref.com/en/players/dc64b8b3/Liam-Cooper',
#  'https://fbref.com/en/players/f4d296e4/Pascal-Struijk',
#  'https://fbref.com/en/players/6c17e046/Tyler-Roberts',
#  'https://fbref.com/en/players/1fb1c435/Rodrigo',
#  'https://fbref.com/en/players/bba30585/Diego-Llorente',
#  'https://fbref.com/en/players/f13d02a6/Helder-Costa',
#  'https://fbref.com/en/players/ea6bc03a/Robin-Koch',
#  'https://fbref.com/en/players/8d03ca5a/Jamie-Shackleton',
#  'https://fbref.com/en/players/c0398aca/Pablo-Hernandez',
#  'https://fbref.com/en/players/58bc7d18/Kiko-Casilla',
#  'https://fbref.com/en/players/5348aada/Gaetano-Berardi',
#  'https://fbref.com/en/players/55b4f1d6/Ian-Carlo-Poveda',
#  'https://fbref.com/en/players/6d646ff7/Niall-Huggins',
#  'https://fbref.com/en/players/8574c61f/Leif-Davis',
#  'https://fbref.com/en/players/a2c1d8c2/Mateusz-Bogusz',
#  'https://fbref.com/en/players/97d7afbd/Elia-Caprile',
#  'https://fbref.com/en/players/2d82641c/Oliver-Casey',
#  'https://fbref.com/en/players/4654e5f5/Charlie-Cresswell',
#  'https://fbref.com/en/players/e0d1510a/Cody-Drameh',
#  'https://fbref.com/en/players/01962d0d/Joe-Gelhardt',
#  'https://fbref.com/en/players/f3354c07/Sam-Greenwood',
#  'https://fbref.com/en/players/3d46127c/Jack-Jenkins',
#  'https://fbref.com/en/players/df04eb4b/Crysencio-Summerville',
#  'https://fbref.com/en/players/c5b7c315/Michael-Keane',
#  'https://fbref.com/en/players/fa031b34/Richarlison',
#  'https://fbref.com/en/players/59e6e5bf/Dominic-Calvert-Lewin',
#  'https://fbref.com/en/players/4806ec67/Jordan-Pickford',
#  'https://fbref.com/en/players/1b84dbe1/Lucas-Digne',
#  'https://fbref.com/en/players/9f7c837d/Ben-Godfrey',
#  'https://fbref.com/en/players/02b29014/Abdoulaye-Doucoure',
#  'https://fbref.com/en/players/d0042ab9/Mason-Holgate',
#  'https://fbref.com/en/players/76dd1480/Gylfi-Sigurdsson',
#  'https://fbref.com/en/players/cc700722/Allan',
#  'https://fbref.com/en/players/6d5701f2/Yerry-Mina',
#  'https://fbref.com/en/players/715bf047/James-Rodriguez',
#  'https://fbref.com/en/players/0420d84f/Seamus-Coleman',
#  'https://fbref.com/en/players/1961b2aa/Andre-Gomes',
#  'https://fbref.com/en/players/6ca5ec4b/Alex-Iwobi',
#  'https://fbref.com/en/players/9228b07c/Tom-Davies',
#  'https://fbref.com/en/players/e7ee38c3/Robin-Olsen',
#  'https://fbref.com/en/players/ab4b3e35/Bernard',
#  'https://fbref.com/en/players/111c3236/Fabian-Delph',
#  'https://fbref.com/en/players/2bd83368/Anthony-Gordon',
#  'https://fbref.com/en/players/f5b281e7/Niels-Nkounkou',
#  'https://fbref.com/en/players/099e666f/Jonjoe-Kenny',
#  'https://fbref.com/en/players/43458538/Joshua-King',
#  'https://fbref.com/en/players/9a104dee/Cenk-Tosun',
#  'https://fbref.com/en/players/728e9b2e/Joao-Virginia',
#  'https://fbref.com/en/players/3d50bcdb/Moise-Kean',
#  'https://fbref.com/en/players/1ecb65be/Theo-Walcott',
#  'https://fbref.com/en/players/6bd603db/Jean-Philippe-Gbamin',
#  'https://fbref.com/en/players/43309491/Nathan-Broadhead',
#  'https://fbref.com/en/players/c9093a1a/Kyle-Alex-John',
#  'https://fbref.com/en/players/0eb884e1/Ryan-Astley',
#  'https://fbref.com/en/players/c1949191/Jarrad-Branthwaite',
#  'https://fbref.com/en/players/939bc634/Jonas-Lossl',
#  'https://fbref.com/en/players/d86a1f3e/Tyler-Onyango',
#  'https://fbref.com/en/players/b9403c99/Isaac-Price',
#  'https://fbref.com/en/players/26d3b5be/Ellis-Simms',
#  'https://fbref.com/en/players/af49fb14/Harry-Tyrer',
#  'https://fbref.com/en/players/a182122b/Reece-Welch',
#  'https://fbref.com/en/players/7956236f/Emiliano-Martinez',
#  'https://fbref.com/en/players/e514ab62/Matt-Targett',
#  'https://fbref.com/en/players/90f91999/John-McGinn',
#  'https://fbref.com/en/players/aed3a70f/Ollie-Watkins',
#  'https://fbref.com/en/players/8397a50c/Tyrone-Mings',
#  'https://fbref.com/en/players/0313a347/Ezri-Konsa',
#  'https://fbref.com/en/players/6f7d826d/Douglas-Luiz',
#  'https://fbref.com/en/players/c47541e0/Bertrand-Traore',
#  'https://fbref.com/en/players/2389cdc2/Matty-Cash',
#  'https://fbref.com/en/players/b0b4fd3e/Jack-Grealish',
#  'https://fbref.com/en/players/3a24769f/Ross-Barkley',
#  'https://fbref.com/en/players/e32958b7/Mark-Gillespie',
#  'https://fbref.com/en/players/096d1e60/Daniel-Langley',
#  'https://fbref.com/en/players/79b0d6a0/Rui-Patricio',
#  'https://fbref.com/en/players/2928dca2/Conor-Coady',
#  'https://fbref.com/en/players/d04b94db/Nelson-Semedo',
#  'https://fbref.com/en/players/44bfb6c5/Ruben-Neves',
#  'https://fbref.com/en/players/7ba2eaa9/Pedro-Neto',
#  'https://fbref.com/en/players/9a28eba4/Adama-Traore',
#  'https://fbref.com/en/players/f5a00fa4/Joao-Moutinho',
#  'https://fbref.com/en/players/5a7301ae/Leander-Dendoncker',
#  'https://fbref.com/en/players/9fbbcf39/Romain-Saiss',
#  'https://fbref.com/en/players/7fcc71d8/Daniel-Podence',
#  'https://fbref.com/en/players/a4ac4b8f/Willy-Boly',
#  'https://fbref.com/en/players/9b398aea/Rayan-Ait-Nouri',
#  'https://fbref.com/en/players/d0f72bf1/Max-Kilman',
#  'https://fbref.com/en/players/d87e2cae/Willian-Jose',
#  'https://fbref.com/en/players/e7aa9d7c/Fabio-Silva',
#  'https://fbref.com/en/players/b561db50/Raul-Jimenez',
#  'https://fbref.com/en/players/9ae9eaea/Fernando-Marcal',
#  'https://fbref.com/en/players/e28868f3/Jonny-Castro',
#  'https://fbref.com/en/players/9a71e978/Ki-Jana-Hoever',
#  'https://fbref.com/en/players/3b029691/Vitinha',
#  'https://fbref.com/en/players/32f60ed8/Morgan-Gibbs-White',
#  'https://fbref.com/en/players/6956ff08/Owen-Otasowie',
#  'https://fbref.com/en/players/b937e490/Ruben-Vinagre',
#  'https://fbref.com/en/players/da8b19e2/John-Ruddy',
#  'https://fbref.com/en/players/a4fe8cda/Patrick-Cutrone',
#  'https://fbref.com/en/players/aa6f2f2c/Oskar-Buur',
#  'https://fbref.com/en/players/25b82f9a/Theo-Corbeanu',
#  'https://fbref.com/en/players/bfc3b3a0/Hugo-Bueno',
#  'https://fbref.com/en/players/cc3b8e78/Luke-Cundle',
#  'https://fbref.com/en/players/178ae8f8/Diogo-Jota',
#  'https://fbref.com/en/players/17be8dc3/Nigel-Lonwijk',
#  'https://fbref.com/en/players/a7cf1541/Christian-Marques',
#  'https://fbref.com/en/players/01ba3996/Taylor-Perry',
#  'https://fbref.com/en/players/ae0e6ba7/Lewis-Richards',
#  'https://fbref.com/en/players/012c38ec/Meritan-Shabani',
#  'https://fbref.com/en/players/43f9b4ba/Andreas-Sondergaard',
#  'https://fbref.com/en/players/ab13a5aa/Vicente-Guaita',
#  'https://fbref.com/en/players/8d3c902d/Cheikhou-Kouyate',
#  'https://fbref.com/en/players/b2bc3b1f/Wilfried-Zaha',
#  'https://fbref.com/en/players/ae4fc6a4/Eberechi-Eze',
#  'https://fbref.com/en/players/2ce2508a/Luka-Milivojevic',
#  'https://fbref.com/en/players/b28bbd58/Andros-Townsend',
#  'https://fbref.com/en/players/8a7ff278/Joel-Ward',
#  'https://fbref.com/en/players/da052c14/Jordan-Ayew',
#  'https://fbref.com/en/players/ab070c55/Christian-Benteke',
#  'https://fbref.com/en/players/7914b9fe/Gary-Cahill',
#  'https://fbref.com/en/players/5f09991f/Patrick-van-Aanholt',
#  'https://fbref.com/en/players/7a1f2c08/Jairo-Riedewald',
#  'https://fbref.com/en/players/5cbd1eb0/Tyrick-Mitchell',
#  'https://fbref.com/en/players/cee31595/James-McArthur',
#  'https://fbref.com/en/players/3312f911/Jeffrey-Schlupp',
#  'https://fbref.com/en/players/52105203/Scott-Dann',
#  'https://fbref.com/en/players/0442183b/Nathaniel-Clyne',
#  'https://fbref.com/en/players/64b08de7/James-McCarthy',
#  'https://fbref.com/en/players/2973d8ff/Michy-Batshuayi',
#  'https://fbref.com/en/players/e7ca0439/James-Tomkins',
#  'https://fbref.com/en/players/87935cf3/Mamadou-Sakho',
#  'https://fbref.com/en/players/50e6dc35/Jean-Philippe-Mateta',
#  'https://fbref.com/en/players/cc70a1d5/Jack-Butland',
#  'https://fbref.com/en/players/d7492450/Martin-Kelly',
#  'https://fbref.com/en/players/974b8e7f/Reece-Hannam',
#  'https://fbref.com/en/players/f234c188/Stephen-Henderson',
#  'https://fbref.com/en/players/76eca7e2/Wayne-Hennessey',
#  'https://fbref.com/en/players/600ae8cb/Ryan-Inniss',
#  'https://fbref.com/en/players/eba42d2b/Max-Meyer',
#  'https://fbref.com/en/players/45685411/Jesuran-Rak-Sakyi',
#  'https://fbref.com/en/players/41cc19c2/Connor-Wickham',
#  ...]

# %%
def fbref_player_info(player_url):
    player_info = []
    for completed, i in enumerate(player_url):

        # PlayerId
        playerId = i.replace("https://fbref.com/en/players/", "").split("/")[0]

        # Request
        r=requests.get(i)
        soup=BeautifulSoup(r.content, "html.parser")

        # Meta
        meta = soup.find("div", {"id":"meta"})

        # Player Name
        playerName = soup.find("h1").find("span").get_text()
        
        # Nationality
        birthplace = meta.find("span", {"itemprop": "birthPlace"}).text.replace("\n", "").strip().split(", ")
        nationality = birthplace[len(birthplace)-1]
        

        # Player Photos
        try:
            photo = soup.find("div", {"class":"media-item"}).find("img").attrs["src"]
        except:
            photo = np.nan


        # Birth
        try:
            birth = meta.find("span", {"itemprop": "birthDate"}).text.replace("\n", "").strip()
            #soup.find("div", {"id":"meta"}).find("span", {"id":"necro-birth"})['data-birth']
        except:
            birth = np.nan

        # Height
        try:
            height = meta.find("span", {"itemprop":"height"}).text.replace("cm", "")
        except:
            height = np.nan

        # Weight
        try:
            weight = soup.find("div", {"id":"meta"}).find("span", {"itemprop":"weight"}).text.replace("kg", "")
        except :
            weight = np.nan


        detail = meta.find_all("p")

        # Player Full Name
        if len(Filter([detail[0].text], ["Position", "Club", "Born", "National Team", "Citizenship"])) > 0:
                playerFullName = np.nan
        else:
            playerFullName = detail[0].get_text()

        # Position & Footed
        fp = list(map(lambda x: str(x), detail))
        position = Filter(fp, ["Position"])
        footed = Filter(fp, ["Footed"])
        if len(position) > 0:
            position = position[0].split("<strong>")[1].replace("Position:</strong>","").replace("\n", "").replace("<p>", "").replace("</p>", "").replace("\xa0", "").replace("▪", "").split("<span")[0].strip()
        else:
            position = np.nan

        if len(footed) > 0:
            footed = footed[0].split("<strong>Footed:</strong>")[1].split("<span")[0].strip().replace("</p>", "").upper()
            footed = footed.split("% ")
            if len(footed) > 1:
                foot = footed[1]
                foot_ability = int(footed[0]) 
            else:
                foot = footed[0]
                foot_ability = 100
        else:
            foot = np.nan
            foot_ability = np.nan

        # International Reputation
        try:
            ir = soup.find("ul", {"id":"bling"}).find_all("a")
            ir = list(map(lambda x: x.text.strip(), ir))
            ir = '||'.join(map(str, ir))  # While the variable will be made || should be separated with
        except:
            ir = np.nan
            
        #Social Media
        sm = Filter(list(map(lambda x: x["href"], meta.find_all("a", href = True))), ["twitter", "instagram"])
        try:
            tw = Filter(sm, ["twitter"])[0]
        except:
            tw = np.nan
        try:
            ins = Filter(sm, ["instagram"])[0]
        except:
            ins = np.nan

        # Data Frame
        temp = pd.DataFrame({
            "FBRefId":[playerId],
            "PlayerName":[playerName],
            "PlayerFullName":[playerFullName],
            "Nationality":[nationality],
            "Photo":[photo],
            "Birth":[birth],
            "Height":[height],
            "Weight":[weight],
            "Position":[position],
            "Foot":[foot],
            "FootAbility":[foot_ability],
            "InternationalReputation":[ir],
            "PlayerUrl":[i],
            "Twitter":[tw],
            "Instagram":[ins]
        })    

        temp["PlayerFullName"] = np.where(temp.PlayerFullName.isnull(), temp.PlayerName, temp.PlayerFullName)

        player_info.append(temp)

        # Print Message
        sys.stdout.write("\r{0} players have just scraped from FBRef!".format(completed+1))
        sys.stdout.flush()

        # System Sleep
        time.sleep(0.01) 

    # Write Player Info
    player_info = pd.concat(player_info)
    
    return player_info

# %%
# Test
player_info = fbref_player_info(player_url)
player_info
# Out:
# 2397 players have just scraped from FBRef!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-bc77eb87a3b1> in <module>
#       1 # Test
# ----> 2 player_info = fbref_player_info(player_url)
#       3 player_info
#
# <ipython-input-50-925bf2b63595> in fbref_player_info(player_url)
#       7
#       8         # Request
# ----> 9         r=requests.get(i)
#      10         soup=BeautifulSoup(r.content, "html.parser")
#      11
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     695
#     696         if not stream:
# --> 697             r.content
#     698
#     699         return r
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in content(self)
#     829                 self._content = None
#     830             else:
# --> 831                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     832
#     833         self._content_consumed = True
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in generate()
#     751             if hasattr(self.raw, 'stream'):
#     752                 try:
# --> 753                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754                         yield chunk
#     755                 except ProtocolError as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     762
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#     766                     break
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/response.py in _update_chunk_length(self)
#     692         if self.chunk_left is not None:
#     693             return
# --> 694         line = self._fp.fp.readline()
#     695         line = line.split(b";", 1)[0]
#     696         try:
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Saving Player Data Dataframe

pd.DataFrame(frame).to_csv('/Volumes/GoogleDrive/.shortcut-targets-by-id/1KUGn_35OjAoOP2puz6yG-2g_8LBxvDG_/SIADS 697 - Capstone/Dataframes/player_data_df.csv', index=False)

# pd.DataFrame(df_39_columns_1).to_csv('/Users/vruiz.CDS/Downloads/Dataframes/consolidated_df.csv', index = False)
